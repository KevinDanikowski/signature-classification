# %% [markdown]
# # Siamese Neural Network
#
# Siamese neural network is a class of neural network architectures that contain two or more identical sub networks. identical here means they have the same configuration with the same parameters and weights. Parameter updating is mirrored across both sub networks.It is used find the similarity of the inputs by comparing its feature vectors.
#
# For more details check this blog : https://innovationincubator.com/siamese-neural-network-with-code-example/

# %% [markdown]
# ## Steps to create classifier using Siamese Neural Network
#
#
# 1.   **Data Preprocessing**
# 2.   **Define the Siamese Network**
# 3.   **Feature Vector Extraction**
# 4.   **Similarity Score Calculation**
# 5.   **Defininf Loss Function**
# 6.   **Optimizer**
# 7.   **Testing using One-Shot Learnig**
# 8.   **Making Predictions**

# %% [markdown]
# Let's  go step wise

# %% [markdown]
# ## Import and Install all the necessary packages

# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

# %% [markdown]
# ### Additional Utility Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# First, look at everything.
sign_data_dir = "./sign_data"
from subprocess import check_output
print(check_output(["ls", sign_data_dir + "/sign_data"]).decode("utf8"))
# Out:
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = sign_data_dir + "/sign_data/train"
    testing_dir = sign_data_dir + "/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 1

# %%
training_dir=sign_data_dir+"/sign_data/train"
training_csv=sign_data_dir+"/sign_data/train_data.csv"
testing_csv=sign_data_dir+"/sign_data/test_data.csv"
testing_dir=sign_data_dir+"/sign_data/test"

# %% [markdown]
# ### Preprocessing and Loading Dataset
#
# We preprocessed all the images and loaded them as .npy files which is easy to transfer . You can follow your own preprocessing steps .

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
# To improve this, we need to rotate and adjust the images
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## Siamese Network Definition

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            
            nn.Conv2d(1, 96, kernel_size=11,stride=1),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

            nn.Conv2d(256,384 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384,256 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

        )
        
        # Defining the fully connected layers
        self.fc1 = nn.Sequential(
            nn.Linear(30976, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.5),
            
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            
            nn.Linear(128,2))
        
  
  
    def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward_once(input1)
        # forward pass of input 2
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ### Loss Function

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ### Train the Model

# %%
# Load the dataset as pytorch tensors using dataloader
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
# Check whether you have GPU is loaded or not
if torch.cuda.is_available():
    print('Yes')

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer
optimizer = optim.RMSprop(net.parameters(), lr=1e-4, alpha=0.99, eps=1e-8, weight_decay=0.0005, momentum=0.9)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-43b48b873e4a> in <module>
#       1 # Declare Siamese Network
# ----> 2 net = SiameseNetwork().cuda()
#       3 # Decalre Loss Function
#       4 criterion = ContrastiveLoss()
#       5 # Declare Optimizer
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     379                 # `with torch.no_grad():`
#     380                 with torch.no_grad():
# --> 381                     param_applied = fn(param)
#     382                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     383                 if should_use_set_data:
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# /usr/local/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     164                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
#     165         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 166             raise AssertionError("Torch not compiled with CUDA enabled")
#     167         if _cudart is None:
#     168             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# Epoch number 0
#  Current loss 2.242238759994507
#
# Epoch number 0
#  Current loss 1.9322509765625
#
# Epoch number 0
#  Current loss 1.2943363189697266
#
# Epoch number 0
#  Current loss 1.1868306398391724
#
# Epoch number 0
#  Current loss 1.649484395980835
#
# Epoch number 0
#  Current loss 1.0747809410095215
#
# Epoch number 0
#  Current loss 1.2423194646835327
#
# Epoch number 0
#  Current loss 1.2720232009887695
#
# Epoch number 0
#  Current loss 1.101806879043579
#
# Epoch number 0
#  Current loss 1.1807559728622437
#
# Epoch number 0
#  Current loss 1.227563500404358
#
# Epoch number 0
#  Current loss 1.0820304155349731
#
# Epoch number 0
#  Current loss 1.5831347703933716
#
# Epoch number 0
#  Current loss 1.2018325328826904
#
# Epoch number 0
#  Current loss 1.2139973640441895
#
# Epoch number 1
#  Current loss 0.9670710563659668
#
# Epoch number 1
#  Current loss 1.168367624282837
#
# Epoch number 1
#  Current loss 1.3020685911178589
#
# Epoch number 1
#  Current loss 1.0921809673309326
#
# Epoch number 1
#  Current loss 1.1865229606628418
#
# Epoch number 1
#  Current loss 1.3427512645721436
#
# Epoch number 1
#  Current loss 1.1606850624084473
#
# Epoch number 1
#  Current loss 1.1745398044586182
#
# Epoch number 1
#  Current loss 1.2500391006469727
#
# Epoch number 1
#  Current loss 1.02895987033844
#
# Epoch number 1
#  Current loss 1.2685085535049438
#
# Epoch number 1
#  Current loss 1.1144452095031738
#
# Epoch number 1
#  Current loss 1.2606873512268066
#
# Epoch number 1
#  Current loss 1.2208561897277832
#
# Epoch number 1
#  Current loss 1.179105281829834
#
# Epoch number 2
#  Current loss 1.28458571434021
#
# Epoch number 2
#  Current loss 1.1191548109054565
#
# Epoch number 2
#  Current loss 1.4164783954620361
#
# Epoch number 2
#  Current loss 1.1418366432189941
#
# Epoch number 2
#  Current loss 1.123513102531433
#
# Epoch number 2
#  Current loss 1.228397011756897
#
# Epoch number 2
#  Current loss 1.0869827270507812
#
# Epoch number 2
#  Current loss 1.2540485858917236
#
# Epoch number 2
#  Current loss 1.163352370262146
#
# Epoch number 2
#  Current loss 1.2630202770233154
#
# Epoch number 2
#  Current loss 1.3723738193511963
#
# Epoch number 2
#  Current loss 1.9544408321380615
#
# Epoch number 2
#  Current loss 1.0862265825271606
#
# Epoch number 2
#  Current loss 1.0171329975128174
#
# Epoch number 2
#  Current loss 1.1786508560180664
#
# Epoch number 3
#  Current loss 1.5856956243515015
#
# Epoch number 3
#  Current loss 1.1672399044036865
#
# Epoch number 3
#  Current loss 1.105027198791504
#
# Epoch number 3
#  Current loss 0.8923672437667847
#
# Epoch number 3
#  Current loss 1.232148289680481
#
# Epoch number 3
#  Current loss 1.1150765419006348
#
# Epoch number 3
#  Current loss 1.238595724105835
#
# Epoch number 3
#  Current loss 1.1897497177124023
#
# Epoch number 3
#  Current loss 1.1524429321289062
#
# Epoch number 3
#  Current loss 1.1150729656219482
#
# Epoch number 3
#  Current loss 1.1428736448287964
#
# Epoch number 3
#  Current loss 1.6165059804916382
#
# Epoch number 3
#  Current loss 1.1802595853805542
#
# Epoch number 3
#  Current loss 1.0694897174835205
#
# Epoch number 3
#  Current loss 1.1926617622375488
#
# Epoch number 4
#  Current loss 1.1723401546478271
#
# Epoch number 4
#  Current loss 1.3560078144073486
#
# Epoch number 4
#  Current loss 1.3411319255828857
#
# Epoch number 4
#  Current loss 1.2315306663513184
#
# Epoch number 4
#  Current loss 1.405403971672058
#
# Epoch number 4
#  Current loss 1.2227208614349365
#
# Epoch number 4
#  Current loss 1.1646814346313477
#
# Epoch number 4
#  Current loss 1.1799657344818115
#
# Epoch number 4
#  Current loss 1.495194911956787
#
# Epoch number 4
#  Current loss 1.1142797470092773
#
# Epoch number 4
#  Current loss 1.2640888690948486
#
# Epoch number 4
#  Current loss 1.131600022315979
#
# Epoch number 4
#  Current loss 1.376772403717041
#
# Epoch number 4
#  Current loss 1.0905826091766357
#
# Epoch number 4
#  Current loss 1.1736462116241455
#
# Epoch number 5
#  Current loss 0.8086653351783752
#
# Epoch number 5
#  Current loss 1.3447129726409912
#
# Epoch number 5
#  Current loss 1.2807812690734863
#
# Epoch number 5
#  Current loss 1.1674203872680664
#
# Epoch number 5
#  Current loss 1.2156713008880615
#
# Epoch number 5
#  Current loss 1.1582558155059814
#
# Epoch number 5
#  Current loss 1.1211740970611572
#
# Epoch number 5
#  Current loss 1.1384546756744385
#
# Epoch number 5
#  Current loss 1.454677939414978
#
# Epoch number 5
#  Current loss 1.1089568138122559
#
# Epoch number 5
#  Current loss 0.9480596780776978
#
# Epoch number 5
#  Current loss 1.7020049095153809
#
# Epoch number 5
#  Current loss 1.285917043685913
#
# Epoch number 5
#  Current loss 1.2070571184158325
#
# Epoch number 5
#  Current loss 1.1454567909240723
#
# Epoch number 6
#  Current loss 1.2590082883834839
#
# Epoch number 6
#  Current loss 1.263864517211914
#
# Epoch number 6
#  Current loss 1.01753568649292
#
# Epoch number 6
#  Current loss 1.2023323774337769
#
# Epoch number 6
#  Current loss 1.1586428880691528
#
# Epoch number 6
#  Current loss 1.332366943359375
#
# Epoch number 6
#  Current loss 1.0990030765533447
#
# Epoch number 6
#  Current loss 1.2752926349639893
#
# Epoch number 6
#  Current loss 1.152103304862976
#
# Epoch number 6
#  Current loss 1.3250898122787476
#
# Epoch number 6
#  Current loss 1.2750649452209473
#
# Epoch number 6
#  Current loss 1.216259479522705
#
# Epoch number 6
#  Current loss 1.1801846027374268
#
# Epoch number 6
#  Current loss 1.1213467121124268
#
# Epoch number 6
#  Current loss 1.2054715156555176
#
# Epoch number 7
#  Current loss 1.6087515354156494
#
# Epoch number 7
#  Current loss 1.0575345754623413
#
# Epoch number 7
#  Current loss 1.1192927360534668
#
# Epoch number 7
#  Current loss 1.0621364116668701
#
# Epoch number 7
#  Current loss 1.3644328117370605
#
# Epoch number 7
#  Current loss 1.1676416397094727
#
# Epoch number 7
#  Current loss 1.22556471824646
#
# Epoch number 7
#  Current loss 1.0134109258651733
#
# Epoch number 7
#  Current loss 1.1472076177597046
#
# Epoch number 7
#  Current loss 1.2346341609954834
#
# Epoch number 7
#  Current loss 1.2654746770858765
#
# Epoch number 7
#  Current loss 1.1855552196502686
#
# Epoch number 7
#  Current loss 1.0664005279541016
#
# Epoch number 7
#  Current loss 1.0863494873046875
#
# Epoch number 7
#  Current loss 1.7445356845855713
#
# Epoch number 8
#  Current loss 1.117286205291748
#
# Epoch number 8
#  Current loss 1.246314525604248
#
# Epoch number 8
#  Current loss 1.065268874168396
#
# Epoch number 8
#  Current loss 1.4216512441635132
#
# Epoch number 8
#  Current loss 1.0891053676605225
#
# Epoch number 8
#  Current loss 1.2609293460845947
#
# Epoch number 8
#  Current loss 1.1371607780456543
#
# Epoch number 8
#  Current loss 1.2729051113128662
#
# Epoch number 8
#  Current loss 1.3494781255722046
#
# Epoch number 8
#  Current loss 1.1918914318084717
#
# Epoch number 8
#  Current loss 1.1928520202636719
#
# Epoch number 8
#  Current loss 1.2774808406829834
#
# Epoch number 8
#  Current loss 1.2746217250823975
#
# Epoch number 8
#  Current loss 1.175865650177002
#
# Epoch number 8
#  Current loss 1.3218204975128174
#
# Epoch number 9
#  Current loss 1.1264216899871826
#
# Epoch number 9
#  Current loss 1.293491244316101
#
# Epoch number 9
#  Current loss 1.1017024517059326
#
# Epoch number 9
#  Current loss 1.314877986907959
#
# Epoch number 9
#  Current loss 1.276888370513916
#
# Epoch number 9
#  Current loss 1.2813242673873901
#
# Epoch number 9
#  Current loss 1.1578359603881836
#
# Epoch number 9
#  Current loss 1.2699739933013916
#
# Epoch number 9
#  Current loss 0.9114084243774414
#
# Epoch number 9
#  Current loss 1.2265353202819824
#
# Epoch number 9
#  Current loss 1.174607753753662
#
# Epoch number 9
#  Current loss 0.9503610134124756
#
# Epoch number 9
#  Current loss 1.3143303394317627
#
# Epoch number 9
#  Current loss 1.74351167678833
#
# Epoch number 9
#  Current loss 0.8708178400993347
#
# Epoch number 10
#  Current loss 1.6722537279129028
#
# Epoch number 10
#  Current loss 1.065619707107544
#
# Epoch number 10
#  Current loss 1.139809250831604
#
# Epoch number 10
#  Current loss 1.3110097646713257
#
# Epoch number 10
#  Current loss 1.0426008701324463
#
# Epoch number 10
#  Current loss 1.1571269035339355
#
# Epoch number 10
#  Current loss 1.1920909881591797
#
# Epoch number 10
#  Current loss 1.0962786674499512
#
# Epoch number 10
#  Current loss 0.9786981344223022
#
# Epoch number 10
#  Current loss 1.1324565410614014
#
# Epoch number 10
#  Current loss 0.8966147899627686
#
# Epoch number 10
#  Current loss 1.1769609451293945
#
# Epoch number 10
#  Current loss 1.2347018718719482
#
# Epoch number 10
#  Current loss 1.1351778507232666
#
# Epoch number 10
#  Current loss 1.1021761894226074
#
# Epoch number 11
#  Current loss 1.1901795864105225
#
# Epoch number 11
#  Current loss 1.1656399965286255
#
# Epoch number 11
#  Current loss 1.3250672817230225
#
# Epoch number 11
#  Current loss 1.1207568645477295
#
# Epoch number 11
#  Current loss 1.0952074527740479
#
# Epoch number 11
#  Current loss 1.1762152910232544
#
# Epoch number 11
#  Current loss 1.1872152090072632
#
# Epoch number 11
#  Current loss 1.413008689880371
#
# Epoch number 11
#  Current loss 0.9968502521514893
#
# Epoch number 11
#  Current loss 1.3047431707382202
#
# Epoch number 11
#  Current loss 1.264753818511963
#
# Epoch number 11
#  Current loss 1.2262942790985107
#
# Epoch number 11
#  Current loss 1.3349599838256836
#
# Epoch number 11
#  Current loss 1.092725157737732
#
# Epoch number 11
#  Current loss 1.1322405338287354
#
# Epoch number 12
#  Current loss 1.2071574926376343
#
# Epoch number 12
#  Current loss 0.8741010427474976
#
# Epoch number 12
#  Current loss 1.1377668380737305
#
# Epoch number 12
#  Current loss 1.2412688732147217
#
# Epoch number 12
#  Current loss 1.1042238473892212
#
# Epoch number 12
#  Current loss 1.3680795431137085
#
# Epoch number 12
#  Current loss 1.1859781742095947
#
# Epoch number 12
#  Current loss 1.0982328653335571
#
# Epoch number 12
#  Current loss 1.21200430393219
#
# Epoch number 12
#  Current loss 1.0512983798980713
#
# Epoch number 12
#  Current loss 1.2344729900360107
#
# Epoch number 12
#  Current loss 1.141758680343628
#
# Epoch number 12
#  Current loss 1.3406497240066528
#
# Epoch number 12
#  Current loss 1.1009231805801392
#
# Epoch number 12
#  Current loss 1.268001914024353
#
# Epoch number 13
#  Current loss 1.2580597400665283
#
# Epoch number 13
#  Current loss 1.169019103050232
#
# Epoch number 13
#  Current loss 1.386204481124878
#
# Epoch number 13
#  Current loss 1.1742901802062988
#
# Epoch number 13
#  Current loss 1.2303383350372314
#
# Epoch number 13
#  Current loss 1.2493059635162354
#
# Epoch number 13
#  Current loss 1.2297916412353516
#
# Epoch number 13
#  Current loss 1.2139432430267334
#
# Epoch number 13
#  Current loss 1.1387765407562256
#
# Epoch number 13
#  Current loss 1.2208865880966187
#
# Epoch number 13
#  Current loss 1.2085790634155273
#
# Epoch number 13
#  Current loss 1.1941025257110596
#
# Epoch number 13
#  Current loss 1.252683401107788
#
# Epoch number 13
#  Current loss 1.688871145248413
#
# Epoch number 13
#  Current loss 1.108550786972046
#
# Epoch number 14
#  Current loss 1.0793852806091309
#
# Epoch number 14
#  Current loss 1.2189786434173584
#
# Epoch number 14
#  Current loss 1.160201072692871
#
# Epoch number 14
#  Current loss 1.3716304302215576
#
# Epoch number 14
#  Current loss 1.02034592628479
#
# Epoch number 14
#  Current loss 1.051389217376709
#
# Epoch number 14
#  Current loss 1.142564058303833
#
# Epoch number 14
#  Current loss 1.2966665029525757
#
# Epoch number 14
#  Current loss 1.1589323282241821
#
# Epoch number 14
#  Current loss 1.2860100269317627
#
# Epoch number 14
#  Current loss 1.1701387166976929
#
# Epoch number 14
#  Current loss 1.1424493789672852
#
# Epoch number 14
#  Current loss 1.1390981674194336
#
# Epoch number 14
#  Current loss 1.2455459833145142
#
# Epoch number 14
#  Current loss 1.2986268997192383
#
# Epoch number 15
#  Current loss 0.8920776844024658
#
# Epoch number 15
#  Current loss 1.211958408355713
#
# Epoch number 15
#  Current loss 1.219123125076294
#
# Epoch number 15
#  Current loss 1.1897950172424316
#
# Epoch number 15
#  Current loss 1.2402257919311523
#
# Epoch number 15
#  Current loss 1.3165802955627441
#
# Epoch number 15
#  Current loss 1.0926436185836792
#
# Epoch number 15
#  Current loss 1.439625859260559
#
# Epoch number 15
#  Current loss 1.148505449295044
#
# Epoch number 15
#  Current loss 1.1961358785629272
#
# Epoch number 15
#  Current loss 1.1870310306549072
#
# Epoch number 15
#  Current loss 1.2008540630340576
#
# Epoch number 15
#  Current loss 1.1524028778076172
#
# Epoch number 15
#  Current loss 1.0444691181182861
#
# Epoch number 15
#  Current loss 1.2316759824752808
#
# Epoch number 16
#  Current loss 1.550719141960144
#
# Epoch number 16
#  Current loss 1.1024136543273926
#
# Epoch number 16
#  Current loss 1.2997770309448242
#
# Epoch number 16
#  Current loss 1.0630958080291748
#
# Epoch number 16
#  Current loss 1.37162184715271
#
# Epoch number 16
#  Current loss 1.2034456729888916
#
# Epoch number 16
#  Current loss 1.3369381427764893
#
# Epoch number 16
#  Current loss 1.3018995523452759
#
# Epoch number 16
#  Current loss 1.2884752750396729
#
# Epoch number 16
#  Current loss 1.2791733741760254
#
# Epoch number 16
#  Current loss 1.1858878135681152
#
# Epoch number 16
#  Current loss 1.2907640933990479
#
# Epoch number 16
#  Current loss 1.2488590478897095
#
# Epoch number 16
#  Current loss 1.1129639148712158
#
# Epoch number 16
#  Current loss 1.7377901077270508
#
# Epoch number 17
#  Current loss 1.243715763092041
#
# Epoch number 17
#  Current loss 1.2715462446212769
#
# Epoch number 17
#  Current loss 1.1156282424926758
#
# Epoch number 17
#  Current loss 1.1586698293685913
#
# Epoch number 17
#  Current loss 1.149062156677246
#
# Epoch number 17
#  Current loss 1.1862201690673828
#
# Epoch number 17
#  Current loss 1.1026270389556885
#
# Epoch number 17
#  Current loss 1.0079509019851685
#
# Epoch number 17
#  Current loss 1.2532638311386108
#
# Epoch number 17
#  Current loss 1.0539441108703613
#
# Epoch number 17
#  Current loss 1.2758246660232544
#
# Epoch number 17
#  Current loss 1.221807837486267
#
# Epoch number 17
#  Current loss 1.6355372667312622
#
# Epoch number 17
#  Current loss 1.1539134979248047
#
# Epoch number 17
#  Current loss 1.1376519203186035
#
# Epoch number 18
#  Current loss 1.1810293197631836
#
# Epoch number 18
#  Current loss 1.1448614597320557
#
# Epoch number 18
#  Current loss 0.9849933981895447
#
# Epoch number 18
#  Current loss 1.2385199069976807
#
# Epoch number 18
#  Current loss 1.1779022216796875
#
# Epoch number 18
#  Current loss 0.9855754375457764
#
# Epoch number 18
#  Current loss 1.1778621673583984
#
# Epoch number 18
#  Current loss 1.204749584197998
#
# Epoch number 18
#  Current loss 1.199343204498291
#
# Epoch number 18
#  Current loss 1.2984254360198975
#
# Epoch number 18
#  Current loss 1.1165038347244263
#
# Epoch number 18
#  Current loss 1.2313477993011475
#
# Epoch number 18
#  Current loss 1.187091588973999
#
# Epoch number 18
#  Current loss 1.2600853443145752
#
# Epoch number 18
#  Current loss 1.1230053901672363
#
# Epoch number 19
#  Current loss 1.1449165344238281
#
# Epoch number 19
#  Current loss 1.246096134185791
#
# Epoch number 19
#  Current loss 1.0383610725402832
#
# Epoch number 19
#  Current loss 1.1137913465499878
#
# Epoch number 19
#  Current loss 1.1993355751037598
#
# Epoch number 19
#  Current loss 1.2217406034469604
#
# Epoch number 19
#  Current loss 1.2368712425231934
#
# Epoch number 19
#  Current loss 1.677046537399292
#
# Epoch number 19
#  Current loss 0.9558773040771484
#
# Epoch number 19
#  Current loss 1.0924444198608398
#
# Epoch number 19
#  Current loss 1.2201683521270752
#
# Epoch number 19
#  Current loss 1.0827441215515137
#
# Epoch number 19
#  Current loss 1.0506236553192139
#
# Epoch number 19
#  Current loss 1.0641460418701172
#
# Epoch number 19
#  Current loss 1.2465916872024536
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model_path = sign_data_dir + '/models/' + 'model-20epochs.pt'
# docs https://pytorch.org/docs/stable/generated/torch.load.html
model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)

# %%
# Print the sample outputs to view its dissimilarity
counter=0

# classes
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])

correct_result = 0
count_max = 140
distance_differentiator = 0.74
dis_original = []
dis_forged = []
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1, output2 = model(x0.to(device),x1.to(device))

  # determine distance between the vectors
  eucledian_distance = F.pairwise_distance(output1, output2)

  is_correct_label = (eucledian_distance.item() >= distance_differentiator and label == list_0) or (eucledian_distance.item() < distance_differentiator and label == list_1) 
  if is_correct_label:
    correct_result += 1

  if label==list_0:
    label="Orginial"
    dis_original.append(eucledian_distance.item())
  else:
    label="Forged"
    dis_forged.append(eucledian_distance.item())
    
  if counter < 1:
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  else: 
    if counter > 1 and counter <= 10:
        print('Dissimilarity: {:.2f} Label: {} ({})'.format(eucledian_distance.item(), label, 'Correct' if is_correct_label else 'Incorrect'))

  counter += 1
  if counter == count_max:
     break
    
print('Correct results:', correct_result / count_max, '%')
# Out:
# Dissimilarity: 0.29 Label: Orginial (Incorrect)
# Dissimilarity: 0.20 Label: Forged (Correct)
# Dissimilarity: 0.33 Label: Orginial (Incorrect)
# Dissimilarity: 0.57 Label: Forged (Correct)
# Dissimilarity: 0.65 Label: Orginial (Incorrect)
# Dissimilarity: 0.81 Label: Forged (Incorrect)
# Dissimilarity: 0.85 Label: Orginial (Correct)
# Dissimilarity: 0.37 Label: Forged (Correct)
# Dissimilarity: 1.26 Label: Forged (Incorrect)
# Correct results: 0.55 %

# %%
df = pd.DataFrame({
    'Origional': dis_original,
})
ax = df.plot.kde(bw_method=0.3)
df = pd.DataFrame({
    'Forged': dis_forged,
})
ax = df.plot.kde(bw_method=0.3)

# %% [markdown]
# ## Final Touch

# %% [markdown]
# Thats it guys ! I am limited by time , computational power and knowledge .to get standard accuracy . But anyway this is the working code of Siamese Neural Network and you can try it for your own applications and dataset.
#
# Paper Reference: https://arxiv.org/pdf/1707.02131.pdf
#
# Thanks to Gupta Blog : https://hackernoon.com/one-shot-learning-with-siamese-networks-in-pytorch-8ddaab10340e
